# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = 'data/main_data.xlsx'
data = pd.read_excel(file_path)

data.head(10)
# Out:
#    Year    State  Democratic %  Gun ownership %    HDI  Unemployment %
# 0  1992  Alabama         0.409            0.552  0.839         0.07525
# 1  1996  Alabama         0.432            0.568  0.850         0.05208
# 2  2000  Alabama         0.416            0.538  0.853         0.04625
# 3  2004  Alabama         0.368            0.516  0.861         0.05575
# 4  2008  Alabama         0.387            0.503  0.867         0.05883
# 5  2012  Alabama         0.384            0.543  0.876         0.08158
# 6  2016  Alabama         0.344            0.528  0.882         0.05908
# 7  2020  Alabama         0.366            0.555  0.879         0.06408
# 8  1992   Alaska         0.303            0.685  0.915         0.08858
# 9  1996   Alaska         0.333            0.663  0.921         0.07425

# %%
for state in data["State"].unique():
    plt.plot(data["Year"].where(data["State"] == state), data["Unemployment %"].where(data["State"] == state))

# %%
plt.figure(figsize=(14, 10))

for state in data["State"].unique():
    state_data = data[data["State"] == state]
    plt.plot(state_data["Year"], state_data["Unemployment %"] * 100, label=state)

plt.xlabel('Year')
plt.ylabel('Unemployment %')
plt.title('Unemployment Rate by State Over Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 10))

for state in data["State"].unique():
    state_data = data[data["State"] == state]
    plt.plot(state_data["Year"], state_data["HDI"], label=state)

plt.xlabel('Year')
plt.ylabel('HDI')
plt.title('HDI by State Over Time')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()
